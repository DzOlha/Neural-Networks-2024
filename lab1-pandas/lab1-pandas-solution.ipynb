# %%
import pandas as pd

# %% [markdown]
# **1. Завантаження датасету за посиланням**

# %%
# download dataset locally
import os
import urllib.request

DOWNLOAD_ROOT = "https://github.com/DzOlha/Neural-Networks-2024/raw/master/lab1-pandas/dataset/"
FILENAME = "student_performance.csv"
URL = DOWNLOAD_ROOT + FILENAME

def fetch_data(url = URL, path = FILENAME):
    urllib.request.urlretrieve(url, path)

# %%
fetch_data()

# %%
# read the data file
def read_data():
  data = pd.read_csv(FILENAME)
  return data;

# %% [markdown]
# **2. Виведення датасету**

# %%
data = read_data()

# %%
data.head()
# Out:
#    StudentID     Name  Gender  AttendanceRate  StudyHoursPerWeek  \
# 0          1     John    Male            85.0                 15
# 1          2    Sarah  Female            90.0                 20
# 2          3     Alex    Male            78.0                 10
# 3          4  Michael    Male            92.0                 25
# 4          5     Emma  Female            88.0                 18
#
#    PreviousGrade  ExtracurricularActivities ParentalSupport  FinalGrade
# 0           78.0                          1            High          80
# 1           85.0                          2          Medium          87
# 2           65.0                          0             Low          68
# 3            NaN                          3            High          92
# 4           82.0                          2          Medium          85

# %% [markdown]
# **3. Перевірити, чи є незаповнені дані NaN і замінити їх на 0.0**

# %%
# check if there are NaN values
data.isnull().any().any()
# Out:
# True

# %%
# replace NaN values with 0.0
data = data.fillna(0.0)

# %%
# check NaN again to make sure we have done replacement
data.isnull().any().any()
# Out:
# False

# %% [markdown]
# **4. Продемонструвати видалення всіх об'єктів з NaN**

# %%
data = read_data()
rows_with_nan = data[data.isnull().any(axis=1)]
len(rows_with_nan)
# Out:
# 2

# %%
# drop all rows with NaN
data = data.dropna()

# %%
len(data[data.isnull().any(axis=1)])
# Out:
# 0

# %%
data.head(10)
# Out:
#    StudentID      Name  Gender  AttendanceRate  StudyHoursPerWeek  \
# 0          1      John    Male            85.0                 15
# 1          2     Sarah  Female            90.0                 20
# 2          3      Alex    Male            78.0                 10
# 4          5      Emma  Female            88.0                 18
# 5          6    Olivia  Female            95.0                 30
# 6          7    Daniel    Male            70.0                  8
# 8          9     James    Male            82.0                 12
# 9         10  Isabella  Female            91.0                 22
#
#    PreviousGrade  ExtracurricularActivities ParentalSupport  FinalGrade
# 0           78.0                          1            High          80
# 1           85.0                          2          Medium          87
# 2           65.0                          0             Low          68
# 4           82.0                          2          Medium          85
# 5           88.0                          1            High          90
# 6           60.0                          0             Low          62
# 8           70.0                          2             Low          72
# 9           86.0                          3            High          88

# %% [markdown]
# **5. Виконати сумування декількох стовбців для додавання підсумкового стовбця.**

# %%
data['sumGrade'] = data[['PreviousGrade', 'FinalGrade']].sum(axis=1);

# %%
data
# Out:
#    StudentID      Name  Gender  AttendanceRate  StudyHoursPerWeek  \
# 0          1      John    Male            85.0                 15
# 1          2     Sarah  Female            90.0                 20
# 2          3      Alex    Male            78.0                 10
# 4          5      Emma  Female            88.0                 18
# 5          6    Olivia  Female            95.0                 30
# 6          7    Daniel    Male            70.0                  8
# 8          9     James    Male            82.0                 12
# 9         10  Isabella  Female            91.0                 22
#
#    PreviousGrade  ExtracurricularActivities ParentalSupport  FinalGrade  \
# 0           78.0                          1            High          80
# 1           85.0                          2          Medium          87
# 2           65.0                          0             Low          68
# 4           82.0                          2          Medium          85
# 5           88.0                          1            High          90
# 6           60.0                          0             Low          62
# 8           70.0                          2             Low          72
# 9           86.0                          3            High          88
#
#    sumGrade
# 0     158.0
# 1     172.0
# 2     133.0
# 4     167.0
# 5     178.0
# 6     122.0
# 8     142.0
# 9     174.0

# %% [markdown]
# **6. За обраними даними зробити проміжні висновки по декількох категоріям**

# %%
data.describe()
# Out:
#        StudentID  AttendanceRate  StudyHoursPerWeek  PreviousGrade  \
# count   8.000000        8.000000            8.00000       8.000000
# mean    5.375000       84.875000           16.87500      76.750000
# std     3.248626        8.043409            7.19995      10.511898
# min     1.000000       70.000000            8.00000      60.000000
# 25%     2.750000       81.000000           11.50000      68.750000
# 50%     5.500000       86.500000           16.50000      80.000000
# 75%     7.500000       90.250000           20.50000      85.250000
# max    10.000000       95.000000           30.00000      88.000000
#
#        ExtracurricularActivities  FinalGrade    sumGrade
# count                    8.00000    8.000000    8.000000
# mean                     1.37500   79.000000  155.750000
# std                      1.06066   10.433463   20.940392
# min                      0.00000   62.000000  122.000000
# 25%                      0.75000   71.000000  139.750000
# 50%                      1.50000   82.500000  162.500000
# 75%                      2.00000   87.250000  172.500000
# max                      3.00000   90.000000  178.000000

# %%
# get min. max, mean of final grades for different genders
data.groupby(['Gender']).agg({'FinalGrade': ['min', 'max', 'mean']})
# Out:
#        FinalGrade
#               min max  mean
# Gender
# Female         85  90  87.5
# Male           62  80  70.5

# %%
data['ExtracurricularActivities'].unique()
# Out:
# array([1, 2, 0, 3])

# %%
# map ExtracurricularActivities to descriptive names
activities = {0: "No", 1: "Moderate", 2: "Active", 3: "Very Active"}
data['ExtracurricularActivities'] = data['ExtracurricularActivities'].map(activities)
data
# Out:
#    StudentID      Name  Gender  AttendanceRate  StudyHoursPerWeek  \
# 0          1      John    Male            85.0                 15
# 1          2     Sarah  Female            90.0                 20
# 2          3      Alex    Male            78.0                 10
# 4          5      Emma  Female            88.0                 18
# 5          6    Olivia  Female            95.0                 30
# 6          7    Daniel    Male            70.0                  8
# 8          9     James    Male            82.0                 12
# 9         10  Isabella  Female            91.0                 22
#
#    PreviousGrade ExtracurricularActivities ParentalSupport  FinalGrade  \
# 0           78.0                  Moderate            High          80
# 1           85.0                    Active          Medium          87
# 2           65.0                        No             Low          68
# 4           82.0                    Active          Medium          85
# 5           88.0                  Moderate            High          90
# 6           60.0                        No             Low          62
# 8           70.0                    Active             Low          72
# 9           86.0               Very Active            High          88
#
#    sumGrade
# 0     158.0
# 1     172.0
# 2     133.0
# 4     167.0
# 5     178.0
# 6     122.0
# 8     142.0
# 9     174.0

# %%
# find a student with highest study hours per week
data.loc[data['StudyHoursPerWeek'].idxmax()].to_frame().T
# Out:
#   StudentID    Name  Gender AttendanceRate StudyHoursPerWeek PreviousGrade  \
# 5         6  Olivia  Female           95.0                30          88.0
#
#   ExtracurricularActivities ParentalSupport FinalGrade sumGrade
# 5                  Moderate            High         90    178.0

# %%
# get the name of a student, who have the biggest score growth
data['ScoreGrowth'] = data['FinalGrade'] - data['PreviousGrade'];
max_growth_index = data['ScoreGrowth'].idxmax()
data.loc[max_growth_index, ['Name', 'Gender', 'ScoreGrowth']].to_frame().T
# Out:
#    Name Gender ScoreGrowth
# 2  Alex   Male         3.0

# %%
# get top-3 students with the lowest score growth
sorted = data.sort_values(by = 'ScoreGrowth', ascending=True)
sorted[['Name', 'Gender', 'ScoreGrowth']].head(3)
# Out:
#      Name  Gender  ScoreGrowth
# 0    John    Male          2.0
# 1   Sarah  Female          2.0
# 5  Olivia  Female          2.0

# %%
# convert acceptance rate into values from 0 to 1
print(data['AttendanceRate'].apply(lambda x: x/100));
# Out:
# 0    0.85
# 1    0.90
# 2    0.78
# 4    0.88
# 5    0.95
# 6    0.70
# 8    0.82
# 9    0.91
# Name: AttendanceRate, dtype: float64

# %%
# get the percentage of male and female in the class
def genderPercentage(gender):
  totalRows = data.shape[0]
  selectedRows = len(data[data['Gender'] == gender])
  return round(selectedRows / totalRows * 100, 2);

print(
  {
    "Female": f"{genderPercentage('Female'):.2f} %",
    "Male percentage": f"{genderPercentage('Male'):.2f} %"
  }
)
# Out:
# {'Female': '50.00 %', 'Male percentage': '50.00 %'}
